# %%
from ultralytics import YOLO
import torch

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.train(
    data="../data/raw/onion_cell_merged_yolo/data.yaml",
    epochs=200,
    imgsz=640,
    device=0,
    name="train"
    )

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category

# %%
results = model("/home/jcibeira/INA/cell_classifier_yolo/data/raw/yolo/images/da950794-stock-photo-root-tip-of-onion-and-mitosis-cell-in-the-root-tip-of-onio_SvrPtvU_jpg.rf.b54398bd2c436c82904fe6ea8bd0efef.jpg")
results[0].show()

# %%
model.save("../models/yolo11n_cell_detection_model.pt")
