# %%
from ultralytics import YOLO
import torch

# %%
import inspect

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.train(
    data="../data/model_output/multiclass_tagged/data.yaml",
    epochs=200,
    imgsz=640,
    device=0,
    name="train"
    )
model.save("../models/yolo11n_cell_clasification_model.pt")

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category

# %%
image = "../data/model_output/multiclass_tagged/test/images/---------Mitotic-cell-division-stages-of-Allium-cepa-L--085_jpg.rf.b68105c7c834652c20bc8b30bc1410e6.jpg"

# %%
results = model(image, classes=[1,2,3,4,5], conf=0.25)  # predict on an image
results[0].show()

# %%
from cell_classifier.utils.plot_yolo_annotations import plot_yolo_annotations

# %%
plot_yolo_annotations("../data/model_output/multiclass_tagged")
